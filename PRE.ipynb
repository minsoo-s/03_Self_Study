# %%
import pandas as pd
import numpy as np

# %%
data1996_2014 = pd.read_csv('../data/발전전력량_추이_1996_2014.csv', encoding='euc-kr',header = 1)
data2015_2021 = pd.read_csv('../data/발전전력량_추이_2015_2021.csv', encoding='euc-kr',header = 1)

# %%
data1996_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 55 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시점        229 non-null    object
#  1   소계        229 non-null    object
#  2   수력        229 non-null    object
#  3   수력.1      229 non-null    object
#  4   수력.2      229 non-null    object
#  5   기력        229 non-null    object
#  6   기력.1      229 non-null    object
#  7   기력.2      229 non-null    object
#  8   기력.3      229 non-null    object
#  9   기력.4      229 non-null    object
#  10  복합화력      229 non-null    object
#  11  복합화력.1    229 non-null    object
#  12  복합화력.2    229 non-null    object
#  13  집단        229 non-null    object
#  14  내연력       229 non-null    object
#  15  대체        229 non-null    object
#  16  원자력       229 non-null    object
#  17  소계.1      229 non-null    object
#  18  수력.3      229 non-null    object
#  19  수력.4      229 non-null    object
# ...

# %%
data1996_2014 = data1996_2014.replace('-',np.nan)

# %%
data1996_2014 = data1996_2014.set_index('시점')

# %%
data1996_2014.head(60)
# Out:
#                소계      수력    수력.1    수력.2        기력    기력.1     기력.2     기력.3  \
# 시점
# 시점             소계      소계      일반      양수        소계     무연탄      유연탄       중유
# 1996.01  16379503  275441     NaN     NaN   8060220     NaN      NaN      NaN
# 1996.02  14946085  273885     NaN     NaN   7295448     NaN      NaN      NaN
# 1996.03  16361713  287330     NaN     NaN   7941015     NaN      NaN      NaN
# 1996.04  15612722  276682     NaN     NaN   7936402     NaN      NaN      NaN
# 1996.05  16057404  327237     NaN     NaN   7819184     NaN      NaN      NaN
# 1996.06  16059728  370382     NaN     NaN   7298169     NaN      NaN      NaN
# 1996.07  17657771  477910     NaN     NaN   7691843     NaN      NaN      NaN
# 1996.08  18147327  444881     NaN     NaN   8708273     NaN      NaN      NaN
# 1996.09  16000820  302732     NaN     NaN   7214316     NaN      NaN      NaN
# 1996.10  16927339  266687     NaN     NaN   7945638     NaN      NaN      NaN
# ...

# %%
data1996_2014.tail(60)
# Out:
#                소계      수력    수력.1    수력.2        기력    기력.1      기력.2  \
# 시점
# 2010.01  39951825  294085   54249  239836  19786031  717764  17228395
# 2010.02  34083915  292083   67817  224265  16667519  629593  14814055
# 2010.03  37038400  290414  122557  167857  18510659  658603  16360985
# 2010.04  33811451  277861  143783  134078  15960563  713885  14195439
# 2010.05  33309452  308954  170982  137972  15539487  604198  14019747
# 2010.06  34294117  329640  136351  193289  16561702  589861  14941002
# 2010.07  37924173  413891  147456  266435  18961500  779072  17050291
# 2010.08  38631509  635651  247985  387667  19255473  780250  17333667
# 2010.09  34360557  657108  269906  387202  17809051  709533  16304966
# 2010.10  34985975  337448  111538  225910  16690936  785807  15554746
# 2010.11  36327620  230582   66443  164139  16673958  721760  15448829
# 2010.12  40665171  324825   63542  261283  19032395  669547  16675365
# ...

# %%
data1996_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 229 entries, 시점 to 2014.12
# Data columns (total 54 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   소계        229 non-null    object
#  1   수력        229 non-null    object
#  2   수력.1      205 non-null    object
#  3   수력.2      205 non-null    object
#  4   기력        229 non-null    object
#  5   기력.1      205 non-null    object
#  6   기력.2      205 non-null    object
#  7   기력.3      205 non-null    object
#  8   기력.4      205 non-null    object
#  9   복합화력      229 non-null    object
#  10  복합화력.1    205 non-null    object
#  11  복합화력.2    204 non-null    object
#  12  집단        13 non-null     object
#  13  내연력       229 non-null    object
#  14  대체        121 non-null    object
#  15  원자력       229 non-null    object
#  16  소계.1      229 non-null    object
#  17  수력.3      229 non-null    object
#  18  수력.4      205 non-null    object
#  19  수력.5      205 non-null    object
# ...

# %%
print(data1996_2014['기력.4'])
# Out:
# 시점
# 시점           LNG
# 1996.01        -
# 1996.02        -
# 1996.03        -
# 1996.04        -
#            ...
# 2014.08        0
# 2014.09        0
# 2014.10        0
# 2014.11     5650
# 2014.12    85650
# Name: 기력.4, Length: 229, dtype: object
